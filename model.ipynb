# %%
#import library
import pandas as pd
import os
import glob
from PIL import Image
import matplotlib.pyplot as plt
from IPython.display import display

# %matplotlib inline

# %%
train_images_dir = "image/training"
test_images_dir = "image/test"

# %%
image_paths = glob.glob(os.path.join(train_images_dir, "*.jpg"))

# %%
counter = 0
for path in image_paths:
    img = Image.open(path)
    display(img)
    counter += 1
    if counter == 5:
        break
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=676x380>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=676x380>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=676x380>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=676x380>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=676x380>
